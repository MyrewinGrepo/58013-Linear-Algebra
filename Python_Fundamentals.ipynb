# %% [markdown]
# <a href="https://colab.research.google.com/github/MyrewinGrepo/58013-Linear-Algebra/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variables and Data Types

# %%
x = 1
a,b = 0, -1
type(x)
y = 1.0
type(y)
x = float(x)
type(x)
s,t,u = "0", '1', 'one'
type(s)
s_int = int(s)
s_int
# Out:
# 0

# %% [markdown]
# #Aritmethic Operations

# %%
a,b,c,d = 2.0,-0.5,0,-32

##Addition
S=a+b
S

##Subraction
D=b-d
D

##Mutiplaction
P=a*d
P

##Division
Q=c/a
Q

##Exponentiation
E=a**b
E
# Out:
# 0.7071067811865476

# %% [markdown]
# #Assingment Operations

# %%
G,H,J,K=0,100,2,2
G+=a
G

H-=d
H

J*=2
J

K**=2
K
# Out:
# 4

# %% [markdown]
# #Comparators

# %%
res_1, res_2, res_3 = 1, 2.0, "1"
true_val = 1.0
## Equality
res_1 == true_val
## Non-equality
res_2 != true_val
## Inequality
t1 = res_1 > res_2
t2 = res_1 < res_2/2
t3 = res_1 >= res_2/2
t4 = res_1 <= res_2
t1
# Out:
# False

# %% [markdown]
# #Logical

# %%
res_1 == true_val
res_1 is true_val
res_1 is not true_val
p, q = True, False
conj = p and q
conj
p, q = True, False
disj = p or q
disjp, q = True, False
nand = not(p and q)
nandp, q = True, False
xor = (not p and q) or (p and not q)
xor
# Out:
# True

# %% [markdown]
# #Input and Output Operations

# %%
print("Hello World")
cnt = 1
string = "Hello World"
print(string, ", Current run count is:", cnt)
cnt += 1
print(f"{string}, Current count is: {cnt}")
sem_grade = 82.243564657461234
name = ""
print("Hello {}, your semestral grade is: {}".format(name, sem_grade))
w_pg, w_mg, w_fg = 0.3, 0.3, 0.4
print("The weights of your semestral grades are:\
\n\t{:.2%} for Prelims\
\n\t{:.2%} for Midterms, and\
\n\t{:.2%} for Finals.".format(w_pg, w_mg, w_fg))
x = input("enter a number: ")
x
name = input("Kimi no nawa: ")
pg = input("Enter prelim grade: ")
mg = input("Enter midterm grade: ")
fg = input("Enter finals grade: ")
sem_grade = None
print("Hello {}, your semestral grade is: {}".format(name, sem_grade))
# Out:
# Hello World
# Hello World , Current run count is: 1
# Hello World, Current count is: 2
# Hello , your semestral grade is: 82.24356465746123
# The weights of your semestral grades are:
# 	30.00% for Prelims
# 	30.00% for Midterms, and
# 	40.00% for Finals.
# enter a number: 2
# Kimi no nawa: yan
# Enter prelim grade: 80
# Enter midterm grade: 90
# Enter finals grade: 78
# Hello yan, your semestral grade is: None

# %% [markdown]
# Looping Statements

# %%
## while loops
i, j = 0, 10
while(i<=j):
  print(f"{i}\t|\t{j}")
i+=1
# for(int i=0; i<10; i++){
# printf(i)
# }
i=0
for i in range(10):
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# 0	|	10
# ...

# %% [markdown]
# #Flow Control

# %%
##Condition Statements

numeral1, numeral2 = 12, 12
if(numeral1 == numeral2):
  print("Yey")
elif(numeral1>numeral2):
  print("Hoho")
else:
  print("Aww")
print("Hip hip")
# Out:
# Yey
# Hip hip

# %% [markdown]
# #Function

# %%
# void DeleteUser(int userid){
# delete(userid);
# }
def delete_user (userid):
  print("Successfully deleted user: {}".format(userid))
def delete_all_users ():
  print("Successfully deleted all users")
